# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import datetime
import pylab

# %matplotlib inline
sns.set_style("whitegrid")
# matplotlib.rcParams['font.sans-serif'] = ['SimHei']
# matplotlib.rcParams['axes.unicode_minus'] = False
pylab.mpl.rcParams['font.sans-serif'] = ['SimHei']  # 指定默认字体
pylab.mpl.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

# %%
import os

f = open('../all_data.csv', encoding='gbk')

df1 = pd.read_csv(f)
df1.columns
# Out:
# d:\python36\lib\site-packages\IPython\core\interactiveshell.py:2705: DtypeWarning: Columns (135,231,241,242) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Unnamed: 0', '用户名MD5', '身份证号MD5', '职业', '芝麻分数', '出生日期', '性别', '下单时间',
#        '商品名称', '商品品牌',
#        ...
#        'AG001001_1', 'AA001016_1', 'AA001015_1', 'AA002001_1', 'AI003003_1',
#        'AK001002_1', 'AK001003_1', 'AI003004_1', 'AK001009_1', 'AK001006_1'],
#       dtype='object', length=497)

# %%
df6 = pd.DataFrame(df1.columns)

df6.columns = ['字段名']
df6 = df6.drop([0])

# %%
f = open('../风控样本数据.csv', encoding='gbk')

df2 = pd.read_csv(f)
df2.shape
# Out:
# d:\python36\lib\site-packages\IPython\core\interactiveshell.py:2705: DtypeWarning: Columns (27,30,33,40,45,50,54,55,59,70,528,550) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (89212, 638)

# %%
f = open('../风控样本数据字典.csv', encoding='gbk')

df3 = pd.read_csv(f)
df3.shape
# Out:
# (797, 5)

# %%
df4 = pd.DataFrame(df2.columns)
df4.columns = {'字段名'}

# %%
df5 = pd.DataFrame(df3['字段名'])
df7 = pd.DataFrame(df3['中文含义'])
df7.columns = ['字段名']

# %%
df8 = pd.merge(df4,df5,on='字段名')

# %%
df9 = pd.concat([df3, df8], axis=1, join='inner')
df9 = pd.DataFrame(df9['中文含义'])
df9
# Out:
#                     中文含义
# 0                     标识
# 1             已知数据样本通过与否
# 2                   用户id
# 3                    用户名
# 4                 用户名MD5
# 5                   用户年龄
# 6                  身份证姓名
# 7                 用户身份证号
# 8                身份证号MD5
# 9                     生日
# 10                    性别
# 11        一线城市公司的地址与户籍匹配
# 12                一线城市户籍
# 13                    职业
# 14             用户手机号码MD5
# 15                 用户手机号
# 16                 收货人姓名
# 17                 收货人号码
# 18                  芝麻分数
# 19       在系统内近六个月被机审拒绝次数
# 20       在系统内近一个月被人审拒绝次数
# 21                   收货市
# 22                   收货省
# 23                   收货区
# 24                订单号MD5
# 25                   订单号
# 26                 总逾期天数
# 27                 总逾期罚金
# 28                订单逾期状态
# 29                 总逾期次数
# ..                   ...
# 512    18个月内租赁人在多个平台申请借款
# 513     1个月内租赁人在多个平台申请借款
# 514    24个月内租赁人在多个平台申请借款
# 515     3个月内租赁人在多个平台申请借款
# 516    60个月内租赁人在多个平台申请借款
# ...

# %%
pd.merge(df6,df8,on='字段名')
# Out:
# Empty DataFrame
# Columns: [字段名]
# Index: []

# %%
df6
# Out:
#                字段名
# 1           用户名MD5
# 2          身份证号MD5
# 3               职业
# 4             芝麻分数
# 5             出生日期
# 6               性别
# 7             下单时间
# 8             商品名称
# 9             商品品牌
# 10            官网价格
# 11             收货省
# 12             收货市
# 13             收货区
# 14              月租
# 15            总账期数
# 16          意外保障价格
# 17            订单状态
# 18            首付时间
# 19            总风险分
# 20          花呗当前状态
# 21          花呗冻结金额
# 22           总逾期罚金
# 23           总逾期天数
# 24           总逾期次数
# 25     芝麻行业关注_风险ID
# 26     芝麻行业关注_查询分数
# 27   芝麻行业关注_查询扩展结果
# 28      芝麻反欺诈_风险ID
# 29      芝麻反欺诈_查询分数
# 30    芝麻反欺诈_查询扩展结果
# ..             ...
# 467     AA001011_1
# 468     AE001003_1
# 469     AA001005_1
# 470     AA001006_1
# 471     AA001004_1
# 472     AA001007_1
# 473     AE001004_1
# 474     AI003001_1
# 475     AE001006_1
# 476     AF003001_1
# 477     AG002001_1
# 478     AA001012_1
# 479     AI003002_1
# 480     AE001007_1
# 481     AD001003_1
# ...

# %%
df8
# Out:
#                                    字段名
# 0                       l_order_id_md5
# 1                     l_user_phone_md5
# 2                    l_user_idcard_md5
# 3                        l_user_gender
# 4                    l_user_occupation
# 5                   l_user_zhima_score
# 6                         l_goods_name
# 7                        l_goods_brand
# 8                   l_goods_final_cost
# 9                  l_order_price_per_m
# 10               l_order_total_payment
# 11                l_order_price_ensure
# 12              l_order_time_first_pay
# 13                      l_huabei_state
# 14               l_huabei_freeze_money
# 15                     l_huabei_freeze
# 16             l_order_overdue_m_state
# 17             l_order_overdue_forfeit
# 18                                 tag
# 19                          l_order_id
# 20                    r_zmwatch_riskid
# 21                     r_zmwatch_score
# 22                    r_zmwatch_result
# ...

# %%
df8
# Out:
#                                    字段名
# 0                       l_order_id_md5
# 1                     l_user_phone_md5
# 2                    l_user_idcard_md5
# 3                        l_user_gender
# 4                    l_user_occupation
# 5                   l_user_zhima_score
# 6                         l_goods_name
# 7                        l_goods_brand
# 8                   l_goods_final_cost
# 9                  l_order_price_per_m
# 10               l_order_total_payment
# 11                l_order_price_ensure
# 12              l_order_time_first_pay
# 13                      l_huabei_state
# 14               l_huabei_freeze_money
# 15                     l_huabei_freeze
# 16             l_order_overdue_m_state
# 17             l_order_overdue_forfeit
# 18                                 tag
# 19                          l_order_id
# 20                    r_zmwatch_riskid
# 21                     r_zmwatch_score
# 22                    r_zmwatch_result
# ...

# %%
df11 = pd.concat([df10, df8], axis=1, join='inner')
df11.columns = ['字段名','中文']
df12 = df11['中文']
df_1 = df1[df10]
df_2 = df2[df12]
target_cols = ['总逾期罚金', '总逾期天数', '总逾期次数']
expired_day_thresh = 14
target_df = df_1[target_cols]
df_1 = df_1.drop(target_cols, axis=1)
df_1['target'] = target_df['总逾期天数'] > expired_day_thresh
df_1['target'] = df_1['target'].apply(lambda x: 1 if x == True else 0)

df_2 = df_2.dropna(subset=['tag'])     
df_2['target'] = df_2['tag'].apply(lambda x: 1 if x == 'nopass' else 0)
df_2 = df_2.drop(['tag'], axis=1)
df_1.shape
# Out:
# (5100, 134)

# %%
df11
# Out:
#                      字段名                       中文
# 0                 用户名MD5           l_order_id_md5
# 1                身份证号MD5         l_user_phone_md5
# 2                     职业        l_user_idcard_md5
# 3                   芝麻分数            l_user_gender
# 4                     性别        l_user_occupation
# 5                   下单时间       l_user_zhima_score
# 6                   商品名称             l_goods_name
# 7                   商品品牌            l_goods_brand
# 8                   官网价格       l_goods_final_cost
# 9                    收货省      l_order_price_per_m
# 10                   收货市    l_order_total_payment
# 11                   收货区     l_order_price_ensure
# 12                    月租   l_order_time_first_pay
# 13                  总账期数           l_huabei_state
# 14                意外保障价格    l_huabei_freeze_money
# 15                  订单状态          l_huabei_freeze
# 16                  首付时间  l_order_overdue_m_state
# 17                  总风险分  l_order_overdue_forfeit
# ...

# %%
df_2.shape
# Out:
# (89208, 136)

# %%
target_cols = ['总逾期罚金', '总逾期天数', '总逾期次数']
expired_day_thresh = 14
target_df = df1[target_cols]
df1_1 = df1.drop(target_cols, axis=1)
df1_1['target'] = target_df['总逾期天数'] > expired_day_thresh
df1_1['target'] = df1_1['target'].apply(lambda x: 1 if x == True else 0)

df2_1 = df2.dropna(subset=['tag'])     
df2_1['target'] = df2_1['tag'].apply(lambda x: 1 if x == 'nopass' else 0)
df2_1 = df2_1.drop(['tag'], axis=1)

df3_1 = df3[['字段名','中文含义']]
# Out:
# d:\python36\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# # 表1，表2带标签

# %%
col1 = pd.DataFrame(df1_1.columns)
col1 = col1.drop([0])
col1.columns = ['中文含义']

col2 = pd.DataFrame(df2_1.columns)
col2.columns = ['字段名']

# %%
df3_2 = df3_1.merge(col1, on='中文含义')
df3_3 = df3_2.merge(col2, on = '字段名')

# %% [markdown]
# # 裁剪表1，表2

# %%
df1_2 = df1_1[df3_3['中文含义']]
df1_2['target'] = df1_1['target']

df2_2 = df2_1[df3_3['字段名']]
df2_2['target'] = df2_1['target']

df1_2.columns = df2_2.columns
# Out:
# d:\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# d:\python36\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df = pd.concat([df1_2,df2_2])

# %%
df = pd.read_csv('../concatDate.csv')

# %%
df[df.columns].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-7470f9a93706> in <module>()
# ----> 1 df[df.columns].unique()
#
# d:\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
binary_convert_cols = []
for col in df:
    if col == 'l_order_id':
        continue
    if len(df[col].unique()) > 1000:
        binary_convert_cols.append(col)
        df[col] = df[col].notnull()
           
print('binary_convert_cols:', binary_convert_cols)
# Out:
# binary_convert_cols: ['Unnamed: 0', 'l_user_idcard_md5', 'l_user_occupation', 'l_order_time_first_pay', 'r_br_riskid', 'r_das_riskid', 'r_ivs_riskid', 'r_jimi_riskid', 'r_sl_contact_order2_inblack_cnt', 'r_sl_riskid', 'r_td_applicate_score', 'r_td_riskid', 'r_zmwatch_riskid']

# %%
df['r_zmwatch_riskid'].unique()
# Out:
# array([ True, False], dtype=bool)

# %%
df2_2[df2_2['target'] == 0]
# Out:
#                       l_user_idcard_md5 l_user_gender l_user_occupation  \
# 2      1c9284b71606d05d98171661a519c8dd             男               NaN
# 3      9183409dc50a6c7fb918eddac7f5ef20             男               NaN
# 4      df449bb198bde7b6c193c3969494d35e             女                学生
# 10     f4e9fbcfc71b4694a924534c7323d9bc             男               NaN
# 13     da239fa09cbc32c6ef8c649679513de0             男               建筑业
# 14     7913c9bb7841cc28eed8bf768838c3bc             女               NaN
# 15     0ed54aad40c6ee002f69c96100e7bb4b             男               NaN
# 18     3f4d59a692c0aa4f6496abb5476c79e1             男               质检员
# 21     5d101e46da3ee9e0829291eb1654508a             男              自主运营
# 24     276cdb0c9a59b6d5e820debd3f3c7903             男               NaN
# 25     c6472f56bd25bde83688792ddd9a6266             男               NaN
# 26     d67b44df9c014eb4b566b8b90aad14a4             男               NaN
# ...
